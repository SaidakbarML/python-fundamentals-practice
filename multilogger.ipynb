# %%
import logging

# %%
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)


logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)


logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  # fixed "message"
    datefmt='%Y-%m-%d %H:%M:%S'

)

# %%
#log messages with diggerent loggers 

logger1.debug('this is a debug message for module1')
logger2.warning('this is a warning message for module 2')

logger2.error('this is an error message')
# Out:
# 2025-06-13 16:49:50 - module1 - DEBUG - this is a debug message for module1
# 2025-06-13 16:49:50 - module2 - WARNING - this is a warning message for module 2
# 2025-06-13 16:49:50 - module2 - ERROR - this is an error message
